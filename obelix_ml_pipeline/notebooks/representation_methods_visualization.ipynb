# %%
from obelix_ml_pipeline.load_representations import load_and_merge_representations_and_experimental_response
from obelix_ml_pipeline.representation_variables import AVAILABLE_SUBSTRATE_REPRESENTATION_TYPES

# %%
# plot dendrograms for all available substrate representations
selected_ligand_representations = ['dft_nbd_model']
selected_substrate_representations = AVAILABLE_SUBSTRATE_REPRESENTATION_TYPES
df = load_and_merge_representations_and_experimental_response(selected_ligand_representations, selected_substrate_representations, plot_dendrograms=True)
